# %%
from dotenv import load_dotenv
import os

load_dotenv()

db_host = os.getenv("DB_HOST")
db_port = os.getenv("DB_PORT")
db_name = os.getenv("DB_NAME")

print(f"Conectando a {db_host}:{db_port}/{db_name}")
# Out:
# Conectando a localhost:5432/ventas_db

# %%
import logging

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

logger = logging.getLogger(__name__)

logger.debug("Esto solo se ve en modo debug")
logger.info("Cargando datos...")
logger.warning("El archivo tiene filas vacias")
logging.error("No se pudo conectar a la base de datos")
# Out:
# 2026-05-26 21:08:22,659 - INFO - Cargando datos...
# 2026-05-26 21:08:22,659 - WARNING - El archivo tiene filas vacias
# 2026-05-26 21:08:22,659 - ERROR - No se pudo conectar a la base de datos
